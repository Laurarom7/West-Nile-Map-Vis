# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#This sends warning messages to the cornfield
import warnings
def ignore_warnings(*args, **kwargs):
    pass
warnings.warn = ignore_warnings

# %%
spray = pd.read_csv('./data/spray_clean.csv')

# %%
from datetime import datetime
spray['Date'] = pd.DatetimeIndex(spray['Date'])

# %%
spray.dtypes
# Out:
# Date         datetime64[ns]
# Latitude            float64
# Longitude           float64
# dtype: object

# %%
spray.set_index('Date',inplace=True)

# %%
spray.head()
# Out:
#              Latitude  Longitude
# Date
# 2011-09-07  41.981433 -87.787777
# 2011-09-07  41.980998 -87.787778
# 2011-09-07  41.980560 -87.787762
# 2011-09-07  41.980198 -87.787758
# 2011-09-07  41.979752 -87.787765

# %% [markdown]
# #### Add Airport Locations

# %% [markdown]
# Station 1: CHICAGO O'HARE INTERNATIONAL AIRPORT Lat: 41.995 Lon: -87.933 Elev: 662 ft. above sea level<br>
# Station 2: CHICAGO MIDWAY INTL ARPT Lat: 41.786 Lon: -87.752 Elev: 612 ft. above sea level

# %%
#ohare, midway locations
airport_lat  = [41.995, 41.786]
airport_long = [-87.933,-87.752]

# %%
a_lat = pd.Series(airport_lat)
a_long = pd.Series(airport_long)

# %%
a_lat
# Out:
# 0    41.995
# 1    41.786
# dtype: float64

# %%
from bokeh.io import output_notebook, show
output_notebook()
import os
from bokeh.models import GMapOptions
from bokeh.plotting import gmap
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ea1ed068-dd59-4120-905b-bf3fb1bd74ad">Loading BokehJS ...</span>
#     </div>

# %%
spray_loc = spray[['Longitude','Latitude']].values

# %%
spray_loc[:,0].shape
# Out:
# (14740,)

# %%
map_options = GMapOptions(lat=41.8781, lng=-87.6298, map_type="roadmap", zoom=10)

# Replace the value below with your personal API key:
api_key = "AIzaSyDRXoS1vC5EDSdB7-U5VqUlGHoGFd4mAQI"

p = gmap(api_key, map_options, title="Chicago")

#data = dict(lat=locations[:,1],
 #           lon=locations[:,0])

#data1 = dict(a_lat=a_lat,
 #          a_long=a_long)

data2 = dict(s_lat=spray_loc[:,1],
             s_long=spray_loc[:,0])


#p.circle(x="lon", y="lat", size=9, fill_color="sienna", fill_alpha=0.8, source=data)
#p.circle(x="a_long",y="a_lat", size = 9, fill_color="dodgerblue",source = data1)
p.circle(x="s_long",y="s_lat",size = 7, fill_color="steelblue", line_color='steelblue',
         fill_alpha=0.6,source=data2,name="Spray Locations 2011 & 2013")
#p.legend()

show(p)
p.to_file(outputfile=”/tmp/myoutputfile.html”)
# Out:
#   <div class="bk-root" id="283fec30-0ae8-48cf-98e1-4676658b29ea"></div>
